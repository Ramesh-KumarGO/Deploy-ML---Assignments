# %% [markdown]
# Hands_on # 1

# %%
for i in range(2,5):
    if i%2==0:
        print("Even Number")
    else:
        print("Odd Number")
# Out:
# Even Number
# Odd Number
# Even Number

# %% [markdown]
# Image of the above execution:
#
# ![Hands_on1%20-%20Q1.png](attachment:Hands_on1%20-%20Q1.png)

# %%
# Task-1: Question2
lst =[]
for n in range(2000, 3200 +1):
    if (n % 7 ==0 and n%5 !=0):
        lst.append(str(n)) 

print((','.join(lst)))
# Out:
# 2002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,2324,2331,2338,2352,2359,2366,2373,2387,2394,2401,2408,2422,2429,2436,2443,2457,2464,2471,2478,2492,2499,2506,2513,2527,2534,2541,2548,2562,2569,2576,2583,2597,2604,2611,2618,2632,2639,2646,2653,2667,2674,2681,2688,2702,2709,2716,2723,2737,2744,2751,2758,2772,2779,2786,2793,2807,2814,2821,2828,2842,2849,2856,2863,2877,2884,2891,2898,2912,2919,2926,2933,2947,2954,2961,2968,2982,2989,2996,3003,3017,3024,3031,3038,3052,3059,3066,3073,3087,3094,3101,3108,3122,3129,3136,3143,3157,3164,3171,3178,3192,3199

# %% [markdown]
# Screen Shot:
# ![T1Q2.png](attachment:T1Q2.png)

# %%
#Task-1: Question3
FL = input("Enter your First & Last Name:")
FN,LN = FL.split()
print('Reversing the order of the names: {1} {0}'.format(FN,LN))
# Out:
# Enter your First & Last Name:U K
# Reversing the order of the names: K U

# %% [markdown]
# Screen Shot:
# ![T1Q3.png](attachment:T1Q3.png)

# %%
#Task-1: Question4

import math

dia = 12
PI = 3.14
#compute volume
Vol = (4/3)* math.pi * (dia/2)**3

print('Volume of a spear with dia= {} is {}'.format(str(dia), str(Vol)))
# Out:
# Volume of a spear with dia= 12 is 904.7786842338603

# %% [markdown]
# Screen shot:
# ![T1Q4.png](attachment:T1Q4.png)

# %%
#Task-2: Question1
lst_1=[]
Num = input('Enter number in sequence:')
Num = Num.split(',')
for n in Num:
    lst_1.append(int(n))
lst_1
# Out:
# Enter number in sequence:1,2,3
# [1, 2, 3]

# %% [markdown]
# Screen Shot:
#     ![T2Q1.png](attachment:T2Q1.png)

# %%
#Task-2: Question2

# %%
#Task-2: Question2
for i in range(1,10):
    if(i<=5):
        for j in range(0,i):
            print('*', end=' ')
        print('')
    else:
        for j in range(10,i,-1):
            print('*', end=' ')
        print('')
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# Screen Shot:
#     ![T2Q2.png](attachment:T2Q2.png)

# %%
#Task-2: Question3

word = input('Enter a word:')
print('Reversed input word is:', word[::-1])
# Out:
# Enter a word:Ramesh
# Reversed input word is: hsemaR

# %% [markdown]
# Screen Shot:
# ![T3Q3.png](attachment:T3Q3.png)

# %%
#Task-2: Question4

print("WE, THE PEOPLE OF INDIA,\n\thaving solemnly resolved to constitute India into a SOVEREIGN, \n\t\t SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC \n\t\t  and to secure to all its citizens")
# Out:
# WE, THE PEOPLE OF INDIA,
# 	having solemnly resolved to constitute India into a SOVEREIGN,
# 		 SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
# 		  and to secure to all its citizens

# %% [markdown]
# Screen shot:
#     ![T2Q4.png](attachment:T2Q4.png)
